# %% [markdown]
# ## DATA MINING (FALL 2022) ASSIGNMENT - 1
# ### Name: Gulraiz Noor Bari
# ### Roll No: 231525536

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from numpy import percentile

# %% [markdown]
# ### Question 1

# %%
data = pd.read_csv('cereal.csv')
data.dropna()
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### Question 2

# %%
print("Mode of MFR Column: ") 
data["mfr"].mode()
# Out:
# Mode of MFR Column:
# 0    K
# Name: mfr, dtype: object

# %%
print("Mode of Type Column: ") 
data["type"].mode()
# Out:
# Mode of Type Column:
# 0    C
# Name: type, dtype: object

# %%
print("Mean of Calories column: ", data["calories"].mean())
print("Mode of Calories Column: ", data["calories"].mode())

print()

print("Five Number Summary:")
print("Min Value: ", data["calories"].min())

quartiles = percentile(data["calories"], [25, 50, 75])
print("Quartile-1: ", quartiles[0])
print("Median of Calories column: ", data["calories"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["calories"].max())
# Out:
# Mean of Calories column:  106.88311688311688
# Mode of Calories Column:  0    110
# Name: calories, dtype: int64
#
# Five Number Summary:
# Min Value:  50
# Quartile-1:  100.0
# Median of Calories column:  110.0
# Quartile-3:  110.0
# Max Value:  160

# %%
print("Mean of Protein Column: ", data["protein"].mean())
print("Mode of Protein Column: ", data["protein"].mode())

print()

print("Five Number Summary:")
print("Min Value: ", data["protein"].min())

quartiles = percentile(data["protein"], [25, 50, 75])
print("Quartile-1: ", quartiles[0])
print("Median of Protein column: ", data["protein"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["protein"].max())
# Out:
# Mean of Protein Column:  2.5454545454545454
# Mode of Protein Column:  0    3
# Name: protein, dtype: int64
#
# Five Number Summary:
# Min Value:  1
# Quartile-1:  2.0
# Median of Protein column:  3.0
# Quartile-3:  3.0
# Max Value:  6

# %%
print("Mean of Fat Column: ", data["fat"].mean())
print("Mode of Fat Column: ", data["fat"].mode())

print()

quartiles = percentile(data["fat"], [25, 50, 75])
print("Five Number Summary:")
print("Min Value: ", data["fat"].min())
print("Quartile-1: ", quartiles[0])
print("Median of Fat column: ", data["fat"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["fat"].max())
# Out:
# Mean of Fat Column:  1.0129870129870129
# Mode of Fat Column:  0    1
# Name: fat, dtype: int64
#
# Five Number Summary:
# Min Value:  0
# Quartile-1:  0.0
# Median of Fat column:  1.0
# Quartile-3:  2.0
# Max Value:  5

# %%
print("Mean of Sodium Column: ", data["sodium"].mean())
print("Mode of Sodium Column: ", data["sodium"].mode())

print()

quartiles = percentile(data["sodium"], [25, 50, 75])
print("Five Number Summary:")
print("Min Value: ", data["sodium"].min())
print("Quartile-1: ", quartiles[0])
print("Median of Sodium column: ", data["sodium"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["sodium"].max())
# Out:
# Mean of Sodium Column:  159.67532467532467
# Mode of Sodium Column:  0    0
# Name: sodium, dtype: int64
#
# Five Number Summary:
# Min Value:  0
# Quartile-1:  130.0
# Median of Sodium column:  180.0
# Quartile-3:  210.0
# Max Value:  320

# %%
print("Mean of Fiber Column: ", data["fiber"].mean())
print("Mode of Fiber Column: ", data["fiber"].mode())

print()

quartiles = percentile(data["fiber"], [25, 50, 75])
print("Five Number Summary:")
print("Min Value: ", data["fiber"].min())
print("Quartile-1: ", quartiles[0])
print("Median of Fiber column: ", data["fiber"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["fiber"].max())
# Out:
# Mean of Fiber Column:  2.1519480519480516
# Mode of Fiber Column:  0    0.0
# Name: fiber, dtype: float64
#
# Five Number Summary:
# Min Value:  0.0
# Quartile-1:  1.0
# Median of Fiber column:  2.0
# Quartile-3:  3.0
# Max Value:  14.0

# %%
print("Mean of Carbo Column: ", data["carbo"].mean())
print("Mode of Carbo Column: ") 
print(data["carbo"].mode())

print()

quartiles = percentile(data["carbo"], [25, 50, 75])
print("Five Number Summary:")
print("Min Value: ", data["carbo"].min())
print("Quartile-1: ", quartiles[0])
print("Median of Carbo column: ", data["carbo"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["carbo"].max())
# Out:
# Mean of Carbo Column:  14.597402597402597
# Mode of Carbo Column:
# 0    13.0
# 1    15.0
# Name: carbo, dtype: float64
#
# Five Number Summary:
# Min Value:  -1.0
# Quartile-1:  12.0
# Median of Carbo column:  14.0
# Quartile-3:  17.0
# Max Value:  23.0

# %%
print("Mean of Sugar Column: ", data["sugars"].mean())
print("Mode of Sugar Column: ", data["sugars"].mode())

print()

quartiles = percentile(data["sugars"], [25, 50, 75])
print("Five Number Summary:")
print("Min Value: ", data["sugars"].min())
print("Quartile-1: ", quartiles[0])
print("Median of Sugar column: ", data["sugars"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["sugars"].max())
# Out:
# Mean of Sugar Column:  6.922077922077922
# Mode of Sugar Column:  0    3
# Name: sugars, dtype: int64
#
# Five Number Summary:
# Min Value:  -1
# Quartile-1:  3.0
# Median of Sugar column:  7.0
# Quartile-3:  11.0
# Max Value:  15

# %%
print("Mean of Potassium Column: ", data["potass"].mean())
print("Mode of Potassium Column: ") 
print(data["potass"].mode())

print()

quartiles = percentile(data["potass"], [25, 50, 75])
print("Five Number Summary:")
print("Min Value: ", data["potass"].min())
print("Quartile-1: ", quartiles[0])
print("Median of Potassium column: ", data["potass"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["potass"].max())
# Out:
# Mean of Potassium Column:  96.07792207792208
# Mode of Potassium Column:
# 0     35
# 1     90
# 2    110
# Name: potass, dtype: int64
#
# Five Number Summary:
# Min Value:  -1
# Quartile-1:  40.0
# Median of Potassium column:  90.0
# Quartile-3:  120.0
# Max Value:  330

# %%
print("Mean of Vitamins Column: ", data["vitamins"].mean())
print("Mode of Vitamins Column: ", data["vitamins"].mode())

print()

quartiles = percentile(data["vitamins"], [25, 50, 75])
print("Five Number Summary:")
print("Min Value: ", data["vitamins"].min())
print("Quartile-1: ", quartiles[0])
print("Median of Vitamins column: ", data["vitamins"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["vitamins"].max())
# Out:
# Mean of Vitamins Column:  28.246753246753247
# Mode of Vitamins Column:  0    25
# Name: vitamins, dtype: int64
#
# Five Number Summary:
# Min Value:  0
# Quartile-1:  25.0
# Median of Vitamins column:  25.0
# Quartile-3:  25.0
# Max Value:  100

# %%
print("Mode of Shelf Column: ") 
data["shelf"].mode()
# Out:
# Mode of Shelf Column:
# 0    3
# Name: shelf, dtype: int64

# %%
print("Mean of Weight Column: ", data["weight"].mean())
print("Mode of Weight Column: ", data["weight"].mode())

print()

quartiles = percentile(data["weight"], [25, 50, 75])
print("Five Number Summary:")
print("Min Value: ", data["weight"].min())
print("Quartile-1: ", quartiles[0])
print("Median of Weight column: ", data["weight"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["weight"].max())
# Out:
# Mean of Weight Column:  1.0296103896103896
# Mode of Weight Column:  0    1.0
# Name: weight, dtype: float64
#
# Five Number Summary:
# Min Value:  0.5
# Quartile-1:  1.0
# Median of Weight column:  1.0
# Quartile-3:  1.0
# Max Value:  1.5

# %%
print("Mean of Cups Column: ", data["cups"].mean())
print("Mode of Cups Column: ", data["cups"].mode())

print()

quartiles = percentile(data["cups"], [25, 50, 75])
print("Five Number Summary:")
print("Min Value: ", data["cups"].min())
print("Quartile-1: ", quartiles[0])
print("Median of Cups column: ", data["cups"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["cups"].max())
# Out:
# Mean of Cups Column:  0.821038961038961
# Mode of Cups Column:  0    1.0
# Name: cups, dtype: float64
#
# Five Number Summary:
# Min Value:  0.25
# Quartile-1:  0.67
# Median of Cups column:  0.75
# Quartile-3:  1.0
# Max Value:  1.5

# %%
print("Mean of Rating Column: ", data["rating"].mean())
print("Mode of Rating Column: ") 
print(data["rating"].mode())

print()

quartiles = percentile(data["rating"], [25, 50, 75])
print("Five Number Summary:")
print("Min Value: ", data["rating"].min())
print("Quartile-1: ", quartiles[0])
print("Median of Rating column: ", data["rating"].median())
print("Quartile-3: ", quartiles[2])
print("Max Value: ", data["rating"].max())
# Out:
# Mean of Rating Column:  42.66570498701299
# Mode of Rating Column:
# 0     18.042851
# 1     19.823573
# 2     21.871292
# 3     22.396513
# 4     22.736446
#         ...
# 72    68.235885
# 73    68.402973
# 74    72.801787
# 75    74.472949
# 76    93.704912
# Name: rating, Length: 77, dtype: float64
#
# Five Number Summary:
# Min Value:  18.042851
# Quartile-1:  33.174094
# Median of Rating column:  40.400208
# Quartile-3:  50.828392
# Max Value:  93.704912

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### a) Is there a relation between sugars, calories, carbs, and fat? (Scatter plot for the above-mentioned attributes)

# %%
# Scatter Matrix
scatter_matrix(data[['calories', 'fat', 'sugars', 'carbo']], figsize=(7, 7))
plt.show()

# Scatter Plot
plt.scatter(data["sugars"], data["calories"], color = "red")
plt.title("Relation between sugars and calories")
plt.xlabel("Sugars")
plt.ylabel("Calories")
plt.show()

plt.scatter(data["sugars"], data["carbo"], color = "green")
plt.title("Relation between sugars and carbs")
plt.xlabel("Sugars")
plt.ylabel("Carbs")
plt.show()

plt.scatter(data["sugars"], data["fat"], color = "blue")
plt.title("Relation between sugars and fat")
plt.xlabel("Sugars")
plt.ylabel("Fat")
plt.show()

plt.scatter(data["carbo"], data["calories"], color = "red")
plt.title("Relation between carbs and calories")
plt.xlabel("Carbs")
plt.ylabel("Calories")
plt.show()

plt.scatter(data["carbo"], data["fat"], color = "green")
plt.title("Relation between carbs and fat")
plt.xlabel("Carbs")
plt.ylabel("Fat")
plt.show()

plt.scatter(data["carbo"], data["sugars"], color = "blue")
plt.title("Relation between carbs and sugars")
plt.xlabel("Carbs")
plt.ylabel("Sugars")
plt.show()

plt.scatter(data["fat"], data["calories"], color = "red")
plt.title("Relation between fat and calories")
plt.xlabel("Fat")
plt.ylabel("Calories")
plt.show()

plt.scatter(data["fat"], data["carbo"], color = "green")
plt.title("Relation between fat and carbs")
plt.xlabel("Fat")
plt.ylabel("Carbs")
plt.show()

plt.scatter(data["fat"], data["sugars"], color = "blue")
plt.title("Relation between fat and sugars")
plt.xlabel("Fat")
plt.ylabel("Sugars")
plt.show()

plt.scatter(data["calories"], data["fat"], color = "red")
plt.title("Relation between fat and calories")
plt.xlabel("Calories")
plt.ylabel("Fat")
plt.show()

plt.scatter(data["calories"], data["carbo"], color = "green")
plt.title("Relation between fat and carbs")
plt.xlabel("Calories")
plt.ylabel("Carbs")
plt.show()

plt.scatter(data["calories"], data["sugars"], color = "blue")
plt.title("Relation between fat and sugars")
plt.xlabel("Calories")
plt.ylabel("Sugars")
plt.show()

# %% [markdown]
# #### b) How are calories and potassium distributed? (Seperate histograms of these attributes with their frequencies)

# %%
# Histogram
plt.hist(data["calories"], color = "red")
plt.title("Calories")
plt.xlabel("Calories")
plt.ylabel("Frequency")
plt.show()

plt.hist(data["potass"], color = "blue")
plt.title("Potassium")
plt.xlabel("Potassium")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### c)	Which manufacturers produce cereal with highest calories? (Bar Graph of the concerned attributes)

# %%
# Bar Graph
plt.bar(data["mfr"], data["calories"], color ='maroon')
plt.xlabel("Manufacturers")
plt.ylabel("Calories")
plt.show()

# %% [markdown]
# #### d)	How does rating compare to calorie count? (Scatter plot of the two attributes)

# %%
plt.scatter(data["rating"], data["calories"], color = "blue")
plt.title("Relation between Rating and Calories")
plt.xlabel("Rating")
plt.ylabel("Calorie")
plt.show()

# %% [markdown]
# #### e)	Which nutrients are essential for a good rating for a cereal? (Scatter matrix for nutrients and ratings of the attributes)

# %%
scatter_matrix(data[['calories', 'fat', 'sugars', 'carbo', 'rating']], figsize=(7, 7))
plt.show()

# %% [markdown]
# #### f) Is there a relation between manufacturer and rating? (Box plots all manufacturers and ratings)

# %%
# Box Plot
data.boxplot(column = "rating", by = "mfr", figsize = (5, 5))
# Out:
# <AxesSubplot: title={'center': 'rating'}, xlabel='mfr'>

# %% [markdown]
# #### g)	Is there a relation between shelf number and rating? (Box plots all shelves and ratings)

# %%
# Correlation
data.boxplot(column = "rating", by = "shelf", figsize = (5, 5))
# Out:
# <AxesSubplot: title={'center': 'rating'}, xlabel='shelf'>
